# %% [markdown]
# 讀取excel(pandas)

# %%
# import openpyxl
import pandas as pd 
df = pd.read_excel('rlc資料.xlsx')
print(df[0:10])

# wb = openpyxl.load_workbook('rlc資料.xlsx',data_only=True)
# print(wb['B5'].value)
# Out:
#         A         B       C          D
# 0  100000 -1.550193  100000 -88.819491
# 1  110000 -1.548037  110000 -88.695968
# 2  120000 -1.545852  120000 -88.570823
# 3  130000 -1.543637  130000 -88.443882
# 4  140000 -1.541387  140000 -88.314963
# 5  150000 -1.539099  150000 -88.183875
# 6  160000 -1.536770  160000 -88.050417
# 7  170000 -1.534395  170000 -87.914378
# 8  180000 -1.531972  180000 -87.775534
# 9  190000 -1.529496  190000 -87.633648

# %% [markdown]
# 提取特定資料

# %%
# df[0:2] row
# df['A'] colume

# %% [markdown]
# Dataframe to list

# %%
x=df['A'].values.tolist()
y=df['B'].values.tolist()

# %% [markdown]
# 畫圖

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='m',alpha=0.5,label='Raw Data')# alpha (0-1)透明度
plt.xlabel('Angular Frequency (rad/s)')
plt.ylabel('Angles (degrees)')
plt.title('RLC Experiment Data')
plt.legend()
plt.show()

# %%
#Git push 測試
